# %%
# !pip install scikit-learn

# %%
# !pip install google-cloud-translate

# %%
# !pip install googletrans

# %%
# !pip install spacy googlemaps requests transformers torch datasets faiss-cpu faiss-gpu numpy

# %%
gmaps_key = 'AIzaSyD8wsLwdy0gyFfTnJBsj2ZA-biZ1OlKHPI'

# %%
import faiss
import numpy as np
from transformers import RagTokenizer, RagSequenceForGeneration
from sklearn.feature_extraction.text import TfidfVectorizer
import googlemaps

# Google Places API 설정
gmaps = googlemaps.Client(key=gmaps_key)

# RAG 모델과 토크나이저 로드
tokenizer = RagTokenizer.from_pretrained("facebook/rag-sequence-nq")
model = RagSequenceForGeneration.from_pretrained("facebook/rag-sequence-nq")

# 구글 리뷰를 수집하는 함수
def fetch_reviews(location, radius=1000):
    places_result = gmaps.places_nearby(location=location, radius=radius, type='restaurant')
    reviews = []

    for place in places_result['results']:
        place_details = gmaps.place(place_id=place['place_id'])
        place_reviews = place_details.get('result', {}).get('reviews', [])
        reviews.extend([review['text'] for review in place_reviews])

    return reviews

# 리뷰 데이터를 벡터화하여 FAISS 인덱스 생성
def create_faiss_index(reviews):
    vectorizer = TfidfVectorizer(stop_words='english')
    X = vectorizer.fit_transform(reviews).toarray().astype('float32')
    dimension = X.shape[1]
    index = faiss.IndexFlatL2(dimension)
    index.add(X)
    return index, vectorizer

# 사용자 입력에 대한 응답 생성 (RAG 모델 사용)
def generate_response_rag(user_input, reviews, index, vectorizer):
    # 사용자 입력을 벡터화
    input_vector = vectorizer.transform([user_input]).toarray().astype('float32')
    # FAISS 인덱스에서 가장 유사한 문서 검색
    distances, indices = index.search(input_vector, k=5)  # k=5: 상위 5개 문서 검색

    # 검색된 리뷰 출력
    context = [reviews[i] for i in indices[0]]

    # RAG 모델을 사용하여 응답 생성
    # Tokenize context and input
    inputs = tokenizer(user_input, return_tensors="pt")
    context_encodings = tokenizer(context, return_tensors="pt", padding=True, truncation=True)

    # Generate response
    outputs = model.generate(
        input_ids=inputs["input_ids"],
        attention_mask=inputs["attention_mask"],
        context_input_ids=context_encodings["input_ids"],
        context_attention_mask=context_encodings["attention_mask"],
        num_beams=4,
        early_stopping=True
    )
    response = tokenizer.decode(outputs[0], skip_special_tokens=True)

    return response, context

# 주요 함수 호출 예시
def main():
    location = (37.5665, 126.978)  # 서울 시청의 좌표 (위도, 경도)
    reviews = fetch_reviews(location)

    if not reviews:
        print("No reviews found.")
        return

    index, vectorizer = create_faiss_index(reviews)

    user_input = "서울에서 좋은 레스토랑 추천해 주세요."
    rag_response, similar_reviews = generate_response_rag(user_input, reviews, index, vectorizer)

    print("RAG Model Generated Response:", rag_response)
    print("Similar Reviews:")
    for review in similar_reviews:
        print("-", review)

if __name__ == "__main__":
    main()
# Out:
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'RagTokenizer'.
# The class this function is called from is 'DPRQuestionEncoderTokenizer'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'RagTokenizer'.
# The class this function is called from is 'DPRQuestionEncoderTokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'RagTokenizer'.
# The class this function is called from is 'BartTokenizer'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'RagTokenizer'.
# The class this function is called from is 'BartTokenizerFast'.
# Some weights of the model checkpoint at facebook/rag-sequence-nq were not used when initializing RagSequenceForGeneration: ['rag.question_encoder.question_encoder.bert_model.pooler.dense.bias', 'rag.question_encoder.question_encoder.bert_model.pooler.dense.weight']
# - This IS expected if you are initializing RagSequenceForGeneration from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RagSequenceForGeneration from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-18-8f2bc669b170> in <cell line: 82>()
#      81
#      82 if __name__ == "__main__":
# ---> 83     main()
#
# <ipython-input-18-8f2bc669b170> in main()
#      73
#      74     user_input = "서울에서 좋은 레스토랑 추천해 주세요."
# ---> 75     rag_response, similar_reviews = generate_response_rag(user_input, reviews, index, vectorizer)
#      76
#      77     print("RAG Model Generated Response:", rag_response)
#
# <ipython-input-18-8f2bc669b170> in generate_response_rag(user_input, reviews, index, vectorizer)
#      49
#      50     # Generate response
# ---> 51     outputs = model.generate(
#      52         input_ids=inputs["input_ids"],
#      53         attention_mask=inputs["attention_mask"],
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     113     def decorate_context(*args, **kwargs):
#     114         with ctx_factory():
# --> 115             return func(*args, **kwargs)
#     116
#     117     return decorate_context
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/rag/modeling_rag.py in generate(self, input_ids, attention_mask, context_input_ids, context_attention_mask, doc_scores, do_deduplication, num_return_sequences, num_beams, n_docs, **model_kwargs)
#    1019             if input_ids is not None:
#    1020                 new_input_ids = input_ids[index : index + 1].repeat(num_candidates, 1)
# -> 1021                 outputs = self(new_input_ids, labels=output_sequences, exclude_bos_score=True)
#    1022             else:  # input_ids is None, need context_input_ids/mask and doc_scores
#    1023                 assert context_attention_mask is not None, (
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1530             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531         else:
# -> 1532             return self._call_impl(*args, **kwargs)
#    1533
#    1534     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1539                 or _global_backward_pre_hooks or _global_backward_hooks
#    1540                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541             return forward_call(*args, **kwargs)
#    1542
#    1543         try:
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/rag/modeling_rag.py in forward(self, input_ids, attention_mask, encoder_outputs, decoder_input_ids, decoder_attention_mask, past_key_values, context_input_ids, context_attention_mask, doc_scores, use_cache, output_attentions, output_hidden_states, output_retrieved, exclude_bos_score, reduce_loss, labels, n_docs, **kwargs)
#     843             use_cache = False
#     844
# --> 845         outputs = self.rag(
#     846             input_ids=input_ids,
#     847             attention_mask=attention_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1530             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531         else:
# -> 1532             return self._call_impl(*args, **kwargs)
#    1533
#    1534     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1539                 or _global_backward_pre_hooks or _global_backward_hooks
#    1540                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541             return forward_call(*args, **kwargs)
#    1542
#    1543         try:
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/rag/modeling_rag.py in forward(self, input_ids, attention_mask, encoder_outputs, decoder_input_ids, decoder_attention_mask, past_key_values, doc_scores, context_input_ids, context_attention_mask, use_cache, output_attentions, output_hidden_states, output_retrieved, n_docs)
#     650                     ).squeeze(1)
#     651             else:
# --> 652                 assert context_input_ids is not None, (
#     653                     "Make sure that `context_input_ids` are passed, if no `retriever` is set. Alternatively, you can"
#     654                     " set a retriever using the `set_retriever(...)` function."
#
# AssertionError: Make sure that `context_input_ids` are passed, if no `retriever` is set. Alternatively, you can set a retriever using the `set_retriever(...)` function.

# %% [markdown]
# 디버깅용 코드

# %% [markdown]
# 구글 리뷰 수집

# %%
import googlemaps

# Google Places API 설정
gmaps = googlemaps.Client(key=gmaps_key)

def fetch_reviews(location, radius=1000):
    try:
        places_result = gmaps.places_nearby(location=location, radius=radius, type='restaurant')
        reviews = []

        for place in places_result['results']:
            place_details = gmaps.place(place_id=place['place_id'])
            place_reviews = place_details.get('result', {}).get('reviews', [])
            reviews.extend([review['text'] for review in place_reviews])

        return reviews
    except Exception as e:
        print(f"Error fetching reviews: {e}")
        return []

# 테스트 코드
location = (37.5665, 126.978)  # 서울 시청의 좌표
reviews = fetch_reviews(location)
print(f"Fetched {len(reviews)} reviews")
#reviews
# Out:
# Fetched 93 reviews

# %% [markdown]
# 2. 한글 리뷰만 추출

# %%
import googlemaps
import re

# Google Places API 설정
gmaps = googlemaps.Client(key=gmaps_key)

def is_korean(text):
    return bool(re.search('[가-힣]', text))

def fetch_reviews(location, radius=1000):
    try:
        places_result = gmaps.places_nearby(location=location, radius=radius, type='restaurant')
        reviews = []

        for place in places_result['results']:
            place_details = gmaps.place(place_id=place['place_id'])
            place_reviews = place_details.get('result', {}).get('reviews', [])
            # 한글 리뷰만 필터링
            korean_reviews = [review['text'] for review in place_reviews if is_korean(review['text'])]
            reviews.extend(korean_reviews)

        return reviews
    except Exception as e:
        print(f"Error fetching reviews: {e}")
        return []

# 테스트 코드
location = (37.5665, 126.978)  # 서울 시청의 좌표
reviews = fetch_reviews(location)
print(f"Fetched {len(reviews)} Korean reviews")
reviews
# Out:
# Fetched 1 Korean reviews
# ['Pretty famous korean restaurant. The food was really good. If you get the course meal you get some of everything. Went and ate the lunch course meal for ₩25,000 per person. Everything was tasty and delicious. They have a main dining area and private rooms for groups. This restaurant is in the basement of the 하나로 building.']

# %% [markdown]
# 반경 10km 검색

# %%
import googlemaps
import time

# Google Maps API 설정
gmaps = googlemaps.Client(key=gmaps_key)

def get_location_from_city(city_name):
    try:
        geocode_result = gmaps.geocode(city_name)
        if geocode_result:
            # 첫 번째 결과의 위치 정보를 사용
            location = geocode_result[0]['geometry']['location']
            return (location['lat'], location['lng'])
        else:
            print(f"Could not find location for city: {city_name}")
            return None
    except Exception as e:
        print(f"Error getting location: {e}")
        return None

def fetch_reviews(location, radius=10000):  # 10km = 10000m
    reviews = []
    next_page_token = None

    while True:
        try:
            # 식당 리뷰 수집
            places_result = gmaps.places_nearby(location=location, radius=radius, type='restaurant', page_token=next_page_token)
            for place in places_result['results']:
                place_name = place['name']
                place_details = gmaps.place(place_id=place['place_id'])
                place_reviews = place_details.get('result', {}).get('reviews', [])
                for review in place_reviews:
                    reviews.append((place_name, review['text']))

            # 관광지 리뷰 수집
            places_result = gmaps.places_nearby(location=location, radius=radius, type='tourist_attraction', page_token=next_page_token)
            for place in places_result['results']:
                place_name = place['name']
                place_details = gmaps.place(place_id=place['place_id'])
                place_reviews = place_details.get('result', {}).get('reviews', [])
                for review in place_reviews:
                    reviews.append((place_name, review['text']))

            # 다음 페이지 토큰 처리
            next_page_token = places_result.get('next_page_token')
            if not next_page_token:
                break

            # Google API 요청 시 대기 시간 추가
            time.sleep(2)

        except Exception as e:
            print(f"Error fetching reviews: {e}")
            break

    return reviews

# 테스트 코드
city_name = input("Enter the city name: ")
location = get_location_from_city(city_name)

if location:
    reviews = fetch_reviews(location)
    if reviews:
        print(f"Fetched {len(reviews)} reviews")
        for place_name, review_text in reviews:
            print(f"Place: {place_name}\nReview: {review_text}\n")
    else:
        print("No reviews found.")
else:
    print("Failed to fetch location.")
# Out:
# Enter the city name: 서울
# Fetched 553 reviews
# Place: Hotel Prince Seoul
# Review: The hotel room is perfect for me as a solo traveller, and the staff were really helpful. My toilet kept flushing and the safe was a little faulty so the staff kindly helped me fix the problem. The location is just nice; a few feet away from the Myeongdong train station, and it’s just across the street from the shopping area!! AND there’s a Starbucks just next to the hotel!! There’s 2 Oliveyoung branches near the hotel, which made it really convenient for shopping, and a nearby small 7-11 convenience store for any late night cravings ☺️✨ I also managed to exchange my small notes for bigger notes with the help of the staff, and they’re willing to go the extra mile to search up the stores I wanted to visit (but didn’t know where the nearest branch was) if they were unsure themselves. Really friendly people, and they have free storage lockers for hotel guests who would like to store their luggages before their check-in time. Outside customers who wish to use their storage lockers may do so at a small price, so I think it’s quite worth it!! It’s located at exit 2 from the Myeongdong station. Would definitely come back again!! :) A huge thankyou to the staff members who helped me!!!
#
# Place: Hotel Prince Seoul
# Review: This is our 2nd time staying at this hotel and the staff are super friendly and helpful.
#
# I left behind a jacket and the staff (didn’t get his full name) not only help me to find but was standing outside the hotel , waiting for my taxi to pass by so that he can just passed over to me.
#
#
# Place: 크로커다일 동대문점
# Review: expensive
#
# Place: 크로커다일 동대문점
# Review:
#
# Place: 크로커다일 동대문점
# Review:
#
# Place: 크로커다일 동대문점
# Review:
#
# Place: The Spoon
# Review: Nice curry! If you can't choose between rice and noodle, order noodle at first and add rice later. Then taste both!
#
# Place: The Spoon
# Review: The mother who cooked and the son who served were very kind and made sure we didn't need anything and asked for more if we needed it. I was very satisfied. The child who went with us also asked to go again next time.
#
# Place: The Spoon
# Review: A curry specialty restaurant located in Chungjeong-ro 6-gil (Miridan-gil?) in Migeun-dong. The restaurants in the area each have their own unique characteristics, just like the restaurants on Gyeongnidan-gil. Perhaps because rents are cheap around here, many small restaurants have opened in recent years. The hall in this house also appears to be only about 5 or 6 pyeong, with tables close together. However, if you go late during lunch time, there are no seats. The curry flavor was different for each menu item and was smooth and delicious. The price range is between 6,500 won and 8,000 won.
#
# Place: The Spoon
# Review: It was a healthy curry. I added sausage and it was really delicious. The food ingredients themselves are of high quality.
#
# Place: The Spoon
# Review: A curry restaurant like a ray of light in Seosomun, a wasteland of taste. Do you sympathize with office workers nearby?
#
# Place: Din Tai Fung Myeongdong
# Review: Great place for a quick lunch when you are craving for dumplings and noodles soup. Selfservice ordering system via a ipad. Food comes relatively quickly. Lots of seating in the restaurant. The entrance is a bit under construction but you won’t notice once inside. Food is tasty!
#
# Place: Din Tai Fung Myeongdong
# Review: it has the quality it should have.
# it's not quite impressive, but safe and didnt go wrong.
#
# Place: Din Tai Fung Myeongdong
# Review: Went for a late lunch and there were lots of tables available. The dumplings and bok choy were delicious.
#
# Place: Din Tai Fung Myeongdong
# Review: I have tried Din Tai Fung all  around the world this was the worse ever. I didnt even feel to be in a DTF restaurant.. and waiters were really unfriendly and unpolite.
#
# Place: Din Tai Fung Myeongdong
# Review: Love DTF!!! Wherever we go around the world, DTF is a must!! Foods here are soo amazingly excellent as usual! Service is top notch!!
#
# Place: The Restaurant
# Review: If you are looking for a fancy date or taking parents out for nice dinner kind of a place, this restaurant is a good fit. Pricy? yes. But their course menu quality was actually pretty good, their atmosphere is fancy, the location is by the palace, and the restaurant is actually located on the 2nd floor of a gallery. We took dinner course and enjoyed them. I would definitely take my parents there for an occasion!
#
# Place: The Restaurant
# Review: Excellent variety of good, very tasty and huge portions. Really enjoyed it.
#
# Place: The Restaurant
# Review: The perfect place to have a peaceful lunch in the center of the action.
#
# Place: The Restaurant
# Review: Service excellent. Customer service is welcoming. Food is delicious. The atmosphere is calm and clean.
#
# Place: The Restaurant
# Review: Surprisingly good! I've never been in a Museum with a good restaurant so this was my first time enjoying a tasty lasagna and the salmon dish.
#
# Very cool.
#
# Place: Candle 1978
# Review: Candle 1978 presents a pleasurable experience within an exquisite setting. Although the menu may lack extensive flexibility, it affords the opportunity for a gratifying lunch. The savory dishes demonstrate both excellence and delectability. Despite commencing with service that was somewhat average and marked by a degree of chaos, the host exhibited exceptional leadership in guiding a diligent team. The team members displayed notable politeness and respect, consistently surpassing expectations to accommodate any requests. We would definitely recommend a visit and will certainly return.
#
# It has five underground levels, and many people who work nearby use long-term parking. Other than that, many customers of naengmyeon restaurants come during lunchtime or on weekends. Even though the total number of parking spaces is almost 500, there are a lot of cars on weekdays. However, in my experience of long-term parking here for 10 years, I have never been unable to park my car.
#
# Parking fee is 800 won per 10 minutes.
# Only card payment is accepted. For payment, there are two parking fee adjustment machines next to the elevator on the first floor. If you eat at a nearby cold noodle restaurant, you will receive a 30-minute free parking ticket. If you insert your free parking ticket into the payment machine, the discount will be applied.
#
# Please note that since it is a public parking lot, discounts are available for the disabled, people with multiple children, compact cars, and low-emission vehicles.
#
# Place: Mukjeong Park
# Review: Mukjeong Children's Park, which opened in 1992, has a children's playground, sports facilities, and sculptures on display above ground, and a public parking lot underground.
# It's great for quick parking when visiting Hamheung Naengmyeon or Busan Galbi Restaurant in Ojang-dong.
#
# Place: 참새어린이공원
# Review: Good
#
# Place: 참새어린이공원
# Review: It’s okay~ There are a lot of rides that kids like.
#
# Place: 참새어린이공원
# Review: Isn’t this the best playground nearby?
#
# Place: 참새어린이공원
# Review: It's a neighborhood playground. It's well made
# Except sometimes older kids play dangerously.
# I commented that it was a really nice place, but I am correcting it.
#
# At a certain time, a group of middle school or high school students gather together to ride on a swing with or without children, kick a ball with or without people around, and talk about alcohol and cigarettes, as well as abusive language.
# It's really serious. If big kids come to play
# Even if it's quiet, you have to play.
#
# Wouldn’t it be difficult to call it a neighborhood playground as it is?
#
# Place: 참새어린이공원
# Review: It is suitable for children to play.
# The bathroom also seems clean and well maintained.
#
# Place: Site of Donuimun Gate (Seodaemun)
# Review: It was the largest gate in the west of the castle surrounding Seoul's old name "Hanyang" a century ago. "Donnymoon" does not exist now and can be viewed as virtual reality. It is now surrounded by office buildings.
#
# Place: Site of Donuimun Gate (Seodaemun)
# Review: I've always wondered why there is no Seodaemun.
# It is said that the current location of Kangbuk Samsung Hospital is the location of Donuimun (Seodaemun).
#
# Well, they say they tried to restore it, but I don't think it will be easy to restore a building that has disappeared so suddenly.
#
# Instead, I have something that can be viewed in VR.
#
# You can guess the appearance of Donuimun Gate.
#
# Saemunan Sinmun-ro Saemun I was curious about this place name.
#
# It is said that Donuimun Gate, which was built during the reign of King Taejong, was rebuilt during the reign of King Sejong.
# What expansion? It feels the same as before
#
# It is said that from then on, the newly created gate was called Shinmun Saemun.
#
# So, Saemoonan Church haha.
#
# I think it's fun to know place names.
#
# Place: Site of Donuimun Gate (Seodaemun)
# Review: Currently, there is no Donuimun Gate, and an old house and village have been built on the site. Currently, the place is being renovated and turned into a private cafe and gallery space for unknown artists to work and communicate!
#
# Place: Site of Donuimun Gate (Seodaemun)
# Review: Leftists and pro-China people are anxious because they can't return the country to Joseon. Instead of wasting tax money on creating fake cultural assets, they should just create distorted Korean history and incorrect contents.
#
# Place: Site of Donuimun Gate (Seodaemun)
# Review: Historical place...well maintained.
#
# Place: Wonhyo Bridge
# Review: Beautiful view of city skyline and Han River
#
# Place: Wonhyo Bridge
# Review: Beautiful clear blue sky view of Nam San Mountain N Tower from Won Hyo Bridge on April 7 2018
#
# Place: Wonhyo Bridge
# Review: Great view and fun to walk across
#
# Place: Wonhyo Bridge
# Review: Just a bridge.
#
# Place: Wonhyo Bridge
# Review: Very nice
#
# Place: Gosanja Bridge
# Review: Seoul's buildings are lined up next to a stream, as if in the countryside.
# Even though it is Seoul, you can go on a bike path and walking tour in a place that looks like a rural area.
#
# Place: Gosanja Bridge
# Review: It's quiet and good for a walk.
# Crossing the Cheonggyecheon Stone Bridge is more charming than crossing a bridge.
#
# Place: Gosanja Bridge
# Review: The 4th Hanmaeum Cheonggyecheon Walking Competition~.
# Departure on June 1, 2019~~
#
# Place: Gosanja Bridge
# Review: A place I always passed by when I went for a run at night.
#
# It is the bridge that I passed whenever I run.
#
# Place: Gosanja Bridge
# Review: Cheongyecheon homeless person sleeping, dancing, Anna, minus 10
#
# Place: Gwanghwamun Square
# Review: There are 5 different story in just one place of Gwanghwamun square.
#
# ☆The Story of the King Sejong has golden statue with clean & air-conditioned museum located underground.
# King Sejong is the person who made korean language and you can see it's picture on the korean money worth 10,000 won bill. (Green)
#
# ☆Yi Sun Shin is the korean great warrior hero with the story of bravery.
# Recomended to watch it's movie.
#
# ☆ Gwangbukgong palace.
# ☆ King sejong open park
# ☆ Monument.
#
# There is a water park that kids will surely enjoy during summer month of July to August. Bring kids extra clothes for changing clothes.
# 🚻 Toilet is available underground
#
# NO admission fee: It's FREE.
#
# Place: Gwanghwamun Square
# Review: When I went they had a Visit Korea festival there.
# A lot of interesting historical landmarks and small installations there. Plently of seating areas too. There's a Seoul Outdoor Library there near the subway station exit area, with seating.
#
# Place: Gwanghwamun Square
# Review: 1/2024
# A very large square, central, and next to Gyeongbokgung Palace. Pretty much every seasonal event is presented here. The US Embassy is across the street, and other tourist attractions are nearby. Wear comfortable walking shies. It is like Vegas. Things seem close, but it takes a little effort to get there by foot. 😉🤙✌️🫶
#
# Place: Gwanghwamun Square
# Review: A picturesque open area which features prominent statues (King Sejong the Great; Admiral Yi Sun-sin), modern architecture and the main entrance to Gyeongbokgung. Nearby places of interest worth visiting include Cheonggyechon Stream, Seoul City Hall, and Deoksugung.
#
# Place: Gwanghwamun Square
# Review: The day we went there was a Seoul Fest on, so it was very busy.
# Lots of displays, pop-up food, a stage for entertainment, and lots of police to keep everyone safe.
# We would suggest a weekday if you don't like the crowds.
#
# Place: Noble Hotel
# Review: Centrally located, reasonable prices, rooms are clean staff and staff very friendly. Brody at the front desk goes above and beyond to ensure the guests are comfortable and suggesting  places to visit. Highly recommend this hotel.
#
# Place: Noble Hotel
# Review: Let me preface by saying that I clearly got unlucky. My friends had two other rooms and were perfectly fine. But if you do get unlucky...
#
# The room was pretty dirty. Not the type of dirt that wasn't cleaned - the type that doesn't come off. All sorts of stains on the walls and the floor. Even the seiling was covered in something weird. The bathroom door had a fist-sized dent in it.
#
# Place: National Museum of Modern and Contemporary Art, Deoksugung
# Review: Modern and contemporary embroidery exhibitions are fantastic.  When I visited during the day on a weekday, I felt like I was back in Korea.
#
# Place: National Museum of Modern and Contemporary Art, Deoksugung
# Review: Absolutely beautiful exhibition when I was here - beautiful grounds lovely building perfect morning out
#
# Place: National Museum of Modern and Contemporary Art, Deoksugung
# Review: Amazing exposition of Korean History of embroidery - very unique and beautiful
#
# Place: National Museum of Modern and Contemporary Art, Deoksugung
# Review: Very bad service…. Here is why👇
# - Discrimination,
# - Height-discrimination,
# - Age discrimination
#
# Price for entry:
# 25 and over -> 2000 Korean Won
# Kids under 24 -> free
#
# Explanation👇🏿
# So we walked in and we were about to buy our ticket for entry, and then we stumbled into this lady with black hair (Korean-looking) we wanted to buy 2 ticket for my parents and get two free tickets for me and my brother. The lady (Korean-looking) asked for out ID, and if we didn’t she said we were the age of 25!!! I showed my ID, and my little brother didn’t have ID with him. So she said to my brother that he was 25?!?!? My little, the age of 13… 25 years????!?!? How is that he even possible???
#
# This is not okay👎🏿👎🏿👎🏿 bad place for (Korean-looking) girl in the ticket-counter

# %% [markdown]
# Faiss 인덱스 생성

# %%
import faiss
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer

def create_faiss_index(reviews):
    try:
        vectorizer = TfidfVectorizer(stop_words='english')
        X = vectorizer.fit_transform(reviews).toarray().astype('float32')
        dimension = X.shape[1]
        index = faiss.IndexFlatL2(dimension)
        index.add(X)
        return index, vectorizer
    except Exception as e:
        print(f"Error creating FAISS index: {e}")
        return None, None

# 테스트 코드
if reviews:
    index, vectorizer = create_faiss_index(reviews)
    if index is not None:
        print("FAISS index created successfully")
    else:
        print("Failed to create FAISS index")
# Out:
# Error creating FAISS index: 'tuple' object has no attribute 'lower'
# Failed to create FAISS index

# %% [markdown]
# 에러수정

# %%
import faiss
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer

def create_faiss_index(reviews):
    try:
        # 모든 리뷰가 문자열인지 확인
        reviews = [str(review) for review in reviews]

        vectorizer = TfidfVectorizer(stop_words='english')
        X = vectorizer.fit_transform(reviews).toarray().astype('float32')

        print(f"Vectorized reviews shape: {X.shape}")

        if X.size == 0:
            raise ValueError("No data to add to the FAISS index.")

        dimension = X.shape[1]
        index = faiss.IndexFlatL2(dimension)

        if X.shape[0] > 0:
            index.add(X)
        else:
            raise ValueError("The input matrix is empty.")

        print(f"Index dimension: {dimension}")
        return index, vectorizer

    except Exception as e:
        print(f"Error creating FAISS index: {e}")
        return None, None

# 테스트 코드
if reviews:
    index, vectorizer = create_faiss_index(reviews)
    if index is not None:
        print("FAISS index created successfully")
    else:
        print("Failed to create FAISS index")
else:
    print("No reviews to process")
# Out:
# Vectorized reviews shape: (553, 2812)
# Index dimension: 2812
# FAISS index created successfully

# %% [markdown]
# RAG 모델 로드

# %%
from transformers import RagTokenizer, RagSequenceForGeneration

def load_rag_model():
    try:
        tokenizer = RagTokenizer.from_pretrained("facebook/rag-sequence-nq")
        model = RagSequenceForGeneration.from_pretrained("facebook/rag-sequence-nq")
        return tokenizer, model
    except Exception as e:
        print(f"Error loading RAG model: {e}")
        return None, None

# 테스트 코드
tokenizer, model = load_rag_model()
if tokenizer and model:
    print("RAG model loaded successfully")
else:
    print("Failed to load RAG model")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'RagTokenizer'.
# The class this function is called from is 'DPRQuestionEncoderTokenizer'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'RagTokenizer'.
# The class this function is called from is 'DPRQuestionEncoderTokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'RagTokenizer'.
# The class this function is called from is 'BartTokenizer'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'RagTokenizer'.
# The class this function is called from is 'BartTokenizerFast'.
# Some weights of the model checkpoint at facebook/rag-sequence-nq were not used when initializing RagSequenceForGeneration: ['rag.question_encoder.question_encoder.bert_model.pooler.dense.bias', 'rag.question_encoder.question_encoder.bert_model.pooler.dense.weight']
# - This IS expected if you are initializing RagSequenceForGeneration from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RagSequenceForGeneration from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# RAG model loaded successfully

# %% [markdown]
# RAG 모델 실행

# %%
import googletrans
from transformers import RagTokenizer, RagSequenceForGeneration
import torch

# 번역 함수 정의
def translate_text(text, target_language='en'):
    translator = googletrans.Translator()
    translation = translator.translate(text, dest=target_language)
    return translation.text

def generate_response_rag(user_input, reviews, index, vectorizer, tokenizer, model):
    try:
        # 사용자 입력을 영어로 번역
        print("번역 시작")
        translated_input = translate_text(user_input)
        if translated_input is None:
            raise ValueError("Translation failed or returned None.")
        print(f"Translated User Input: {translated_input}")

        # 사용자 입력을 벡터화
        print("입력 벡터화")
        input_vector = vectorizer.transform([translated_input]).toarray().astype('float32')
        print(f"입력벡터 출력 : {input_vector.shape}")

        # FAISS 인덱스에서 가장 유사한 문서 검색
        print("유사한 문서 검색")
        distances, indices = index.search(input_vector, k=5)  # k=5: 상위 5개 문서 검색
        print(f"Distances: {distances}")
        print(f"Indices: {indices}")

        # 검색된 리뷰 출력
        context = [reviews[i] for i in indices[0]]
        print("검색된 리뷰 출력")
        for i, review in enumerate(context):
            print(f"Context {i}: {review}")

        # RAG 모델을 사용하여 응답 생성
        print("Tokenizing user input and context...")
        inputs = tokenizer(translated_input, return_tensors="pt")
        context_encodings = tokenizer(context, return_tensors="pt", padding=True, truncation=True)

        # Model inputs 확인
        print("Model inputs:")
        print(f"User input IDs: {inputs['input_ids']}")
        print(f"User input attention mask: {inputs['attention_mask']}")
        print(f"Context input IDs: {context_encodings['input_ids']}")
        print(f"Context attention mask: {context_encodings['attention_mask']}")

        # Generate response
        print("Generating response...")
        outputs = model.generate(
            input_ids=inputs["input_ids"].to(model.device),
            attention_mask=inputs["attention_mask"].to(model.device),
            decoder_input_ids=context_encodings["input_ids"].to(model.device),
            decoder_attention_mask=context_encodings["attention_mask"].to(model.device),
            num_beams=4,
            early_stopping=True,
            max_length=50  # 생성 길이를 조절
        )
        response = tokenizer.decode(outputs[0], skip_special_tokens=True)

        return response, context
    except Exception as e:
        print(f"Error generating response: {e}")
        return None, []

# 테스트 코드
if tokenizer and model and reviews:
    user_input = "한국의 역사적인 내용이 많이 담겨있는 관광지를 가고싶어"
    rag_response, similar_reviews = generate_response_rag(user_input, reviews, index, vectorizer, tokenizer, model)

    if rag_response:
        print("RAG Model Generated Response:", rag_response)
        print("Similar Reviews:")
        for review in similar_reviews:
            print("-", review)
    else:
        print("Failed to generate response")
# Out:
# 번역 시작
# Error generating response: 'NoneType' object has no attribute 'group'
# Failed to generate response

# %% [markdown]
# 번역

# %%
from google.cloud import translate_v2 as translate

def translate_text(text, target_language='en'):
    try:
        translate_client = translate.Client()
        result = translate_client.translate(text, target_language=target_language)
        return result['translatedText']
    except Exception as e:
        print(f"Translation error: {e}")
        return None

# 테스트 코드
user_input = "한국의 역사적인 내용이 많이 담겨있는 관광지를 가고싶어"
translated_input = translate_text(user_input)
print(f"Translated Input: {translated_input}")
# Out:
# Translation error: ("Failed to retrieve http://metadata.google.internal/computeMetadata/v1/instance/service-accounts/default/?recursive=true from the Google Compute Engine metadata service. Status: 404 Response:\nb''", <google.auth.transport.requests._Response object at 0x795b46452020>)
# Translated Input: None
